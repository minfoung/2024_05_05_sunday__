# %%
import numpy as np
import pandas as pd

s1 = pd.Series(np.random.randn(9),
          index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                 [1, 2, 3, 1, 2, 3, 1, 2, 3]])
s1.index.names = ['key1','key2']
s1
# Out:
# key1  key2
# a     1       1.462727
#       2       1.236623
#       3       0.808062
# b     1      -0.660697
#       2      -0.898469
# c     3      -1.339797
#       1       0.074242
# d     2      -1.616230
#       3       1.329685
# dtype: float64

# %%
s2 = pd.Series(np.random.randn(9),
          index=pd.MultiIndex.from_arrays([
              ['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
              [1, 2, 3, 1, 2, 3, 1, 2, 3]
              ],names=['key1','key2']))
s2
# Out:
# key1  key2
# a     1       0.123511
#       2       1.380520
#       3      -0.532258
# b     1      -0.610902
#       2       1.052351
# c     3       0.026814
#       1       1.621489
# d     2       0.265379
#       3      -0.415871
# dtype: float64

# %%
display(s2.unstack("key2",fill_value=0))
s2.unstack("key1",fill_value=0)
# Out:
# key2         1         2         3
# key1
# a     0.123511  1.380520 -0.532258
# b    -0.610902  1.052351  0.000000
# c     1.621489  0.000000  0.026814
# d     0.000000  0.265379 -0.415871
# key1         a         b         c         d
# key2
# 1     0.123511 -0.610902  1.621489  0.000000
# 2     1.380520  1.052351  0.000000  0.265379
# 3    -0.532258  0.000000  0.026814 -0.415871

# %%
s3 = s2.unstack("key1",fill_value=0)
s3.T
# Out:
# key2         1         2         3
# key1
# a     0.123511  1.380520 -0.532258
# b    -0.610902  1.052351  0.000000
# c     1.621489  0.000000  0.026814
# d     0.000000  0.265379 -0.415871

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=pd.MultiIndex.from_arrays([['a','a','b','b'],[1, 2, 1, 2]],names=['key1','key2']),
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
frame['台北']
# Out:
# 顏色         Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame['台北']['Green']
# Out:
# key1  key2
# a     1       0
#       2       3
# b     1       6
#       2       9
# Name: Green, dtype: int64

# %%
display(frame)
frame.loc['a']
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11
# 縣市      台北        台中
# 顏色   Green Red Green
# key2
# 1        0   1     2
# 2        3   4     5

# %%
display(frame)
frame.loc['a']['台中']
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11
# 顏色    Green
# key2
# 1         2
# 2         5

# %%
#堆疊資料
display(frame.stack(level='縣市'))
display(frame.stack(level=['縣市','顏色']))

# %%
s1 = frame.stack(level=['縣市','顏色'])
s1.unstack(level=['key1','顏色'])
